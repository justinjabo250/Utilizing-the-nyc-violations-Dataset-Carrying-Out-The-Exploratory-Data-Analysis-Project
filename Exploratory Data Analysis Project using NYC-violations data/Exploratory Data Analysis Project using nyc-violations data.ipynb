# %% [markdown]
# <!-- Using the same nyc-ticket-violation dataset, let's assume that tickets can
# be dismissed if the license plate, state, and/or street name are all there
# but without requiring the make of car.
# Remove rows that are missing one or more of these.
# How many rows remain? Assuming $100/ticket, how much money would the city lose as a result of this? -->

# %% [markdown]
# # Using the same nyc-ticket-violation dataset, let’s assume that tickets can be dismissed if the license plate, state, and/or street name are all there but without requiring the make of car. Remove rows that are missing one or more of these. How many rows remain? Assuming 100 / ticket, how much money would the city lose as a result of this?

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('data.csv', usecols=['Plate ID', 'Registration State', 'Vehicle Make', 'Vehicle Color', 'Violation Time', 'Street Name'])

# %%
df.shape
# Out:
# (50113, 6)

# %%
df.head()
# Out:
#   Plate ID Registration State Vehicle Make Violation Time  \
# 0  KGK6659                 NY          BMW          0637P
# 1  L5232HY                 TN        INTER          0853A
# 2   BPMN76                 FL        NISSA          0853A
# 3  57387MJ                 NY          NaN          0444P
# 4   M81KFJ                 NJ        TOYOT          0723A
#
#             Street Name Vehicle Color
# 0  WB ATLANTIC AVE @ SH            GY
# 1   Rockaway Beach Blvd         WHITE
# 2            W 113th St         BLACK
# 3             W 33rd St            WH
# 4  WB FOSTER AVE @ E 18           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50113 entries, 0 to 50112
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Plate ID            50000 non-null  object
#  1   Registration State  50000 non-null  object
#  2   Vehicle Make        49864 non-null  object
#  3   Violation Time      49999 non-null  object
#  4   Street Name         49990 non-null  object
#  5   Vehicle Color       47583 non-null  object
# dtypes: object(6)
# memory usage: 2.3+ MB

# %%
# count rows with missing data
df.isnull().sum()
# Out:
# Plate ID               113
# Registration State     113
# Vehicle Make           249
# Violation Time         114
# Street Name            123
# Vehicle Color         2530
# dtype: int64

# %%
no_na=df.dropna()

# %%
no_na
# Out:
#       Plate ID Registration State Vehicle Make Violation Time  \
# 0      KGK6659                 NY          BMW          0637P
# 1      L5232HY                 TN        INTER          0853A
# 2       BPMN76                 FL        NISSA          0853A
# 5      KDW9420                 NY        INFIN          0655P
# 6      HLB4150                 NY        HONDA          1049A
# ...        ...                ...          ...            ...
# 49995  JPN4910                 NY         FORD          0342P
# 49996   174ZYG                 CT        TOYOT          0828A
# 49997  HES6895                 NY        CADIL          0933P
# 49998  63035MN                 NY        ISUZU          1215P
# 49999  AW74165                 CT        HONDA          0128P
#
#                 Street Name Vehicle Color
# 0      WB ATLANTIC AVE @ SH            GY
# 1       Rockaway Beach Blvd         WHITE
# 2                W 113th St         BLACK
# 5      NB KNAPP ST @ VOORHI            BK
# ...

# %%
no_na.shape
# Out:
# (47446, 6)

# %%
no_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47446 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Plate ID            47446 non-null  object
#  1   Registration State  47446 non-null  object
#  2   Vehicle Make        47446 non-null  object
#  3   Violation Time      47446 non-null  object
#  4   Street Name         47446 non-null  object
#  5   Vehicle Color       47446 non-null  object
# dtypes: object(6)
# memory usage: 2.5+ MB

# %%
del_row = df.shape[0] - no_na.shape[0]

# %%
del_row
# Out:
# 2667

# %%
del_row * 100
# Out:
# 266700

# %%
# Drop columns with NaNs
new_df = df.dropna(subset=['Plate ID', 'Registration State', 'Street Name'])

# %%
new_df.shape[0]
# Out:
# 49990

# %%
new_df = df.dropna()

# %%
new_df.shape[0]
# Out:
# 47446

# %%
# (df.shape[0] - new_df.shape[0]) * 100

# %%
delete_rows = (df.shape[0] - new_df.shape[0]) * 100

# %%
delete_rows
# Out:
# 266700

# %% [markdown]
# # For your Individual Project, using the same nyc-violations data, conduct an Exploratory Data Analysis on the dataset and produce a report in your Jupyter Notebook describing insights gleaned from the dataset. Please note that this EDA report must contain appropriate visualizations, to show trends and insights gleaned.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('data.csv')
# Out:
# /var/folders/d9/bnlf1kp95215c4604jd3mz1h0000gn/T/ipykernel_81309/625188700.py:1: DtypeWarning: Columns (34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('data.csv')

# %%
df.head(1000)
# Out:
#      Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      4.714702e+09  KGK6659                 NY        PAS    11-12-20
# 1      8.793685e+09  L5232HY                 TN        PAS  09/14/2020
# 2      8.864757e+09   BPMN76                 FL        PAS  11/25/2020
# 3      8.778326e+09  57387MJ                 NY        COM  08/20/2020
# 4      4.706641e+09   M81KFJ                 NJ        PAS    09-09-20
# ..              ...      ...                ...        ...         ...
# 995    8.799033e+09  78754MN                 NY        COM  10/13/2020
# 996    8.805721e+09  ERG2200                 NY        PAS    08-05-20
# 997    8.643890e+09   43LA64                 SD        PAS    09-02-20
# 998    8.745228e+09  HGM6190                 NY        PAS    08-06-20
# 999    8.853851e+09  56245MG                 NY        COM    09-10-20
#
#      Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# ...

# %%
df.isnull().sum()
# Out:
# Summons Number                         113
# Plate ID                               113
# Registration State                     113
# Plate Type                             113
# Issue Date                             113
# Violation Code                         113
# Vehicle Body Type                      258
# Vehicle Make                           249
# Issuing Agency                         113
# Street Code1                           113
# Street Code2                           113
# Street Code3                           113
# Vehicle Expiration Date                113
# Violation Location                   18005
# Violation Precinct                     113
# Issuer Precinct                        113
# Issuer Code                            113
# Issuer Command                       17969
# Issuer Squad                         17969
# Violation Time                         114
# Time First Observed                  48224
# Violation County                       230
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Summons Number, Plate ID, Registration State, Plate Type, Issue Date, Violation Code, Vehicle Body Type, Vehicle Make, Issuing Agency, Street Code1, Street Code2, Street Code3, Vehicle Expiration Date, Violation Location, Violation Precinct, Issuer Precinct, Issuer Code, Issuer Command, Issuer Squad, Violation Time, Time First Observed, Violation County, Violation In Front Of Or Opposite, House Number, Street Name, Intersecting Street, Date First Observed, Law Section, Sub Division, Violation Legal Code, Days Parking In Effect    , From Hours In Effect, To Hours In Effect, Vehicle Color, Unregistered Vehicle?, Vehicle Year, Meter Number, Feet From Curb, Violation Post Code, Violation Description, No Standing or Stopping Violation, Hydrant Violation, Double Parking Violation, Unnamed: 43, Unnamed: 44]
# Index: []
#
# [0 rows x 45 columns]

# %%
df
# Out:
#        Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0        4.714702e+09  KGK6659                 NY        PAS    11-12-20
# 1        8.793685e+09  L5232HY                 TN        PAS  09/14/2020
# 2        8.864757e+09   BPMN76                 FL        PAS  11/25/2020
# 3        8.778326e+09  57387MJ                 NY        COM  08/20/2020
# 4        4.706641e+09   M81KFJ                 NJ        PAS    09-09-20
# ...               ...      ...                ...        ...         ...
# 50108             NaN      NaN                NaN        NaN         NaN
# 50109             NaN      NaN                NaN        NaN         NaN
# 50110             NaN      NaN                NaN        NaN         NaN
# 50111             NaN      NaN                NaN        NaN         NaN
# 50112             NaN      NaN                NaN        NaN         NaN
#
#        Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# ...

# %%
df.shape
# Out:
# (50113, 45)

# %%
df['Registration State'].value_counts()
# Out:
# NY    36761
# NJ     5202
# PA     1531
# FL     1058
# CT      746
# TX      579
# VA      402
# IN      369
# MA      369
# MD      325
# NC      301
# GA      266
# OH      194
# IL      171
# CA      155
# ME      143
# AZ      143
# TN      131
# SC       94
# DE       85
# MI       80
# MN       72
# 99       70
# WA       68
# GV       65
# AL       63
# VT       52
# RI       49
# OK       45
# NH       44
# MO       38
# OR       32
# WI       30
# KY       28
# LA       28
# CO       26
# DC       23
# MS       19
# WV       18
# IA       14
# UT       13
# AR       13
# NM       11
# NV        8
# KS        7
# SD        7
# ON        7
# QB        7
# MT        7
# ID        6
# NE        5
# DP        4
# AB        4
# AK        3
# ND        3
# HI        2
# PR        2
# FO        1
# WY        1
# Name: Registration State, dtype: int64

# %%
df['Registration State'].value_counts()
# Out:
# NY    36761
# NJ     5202
# PA     1531
# FL     1058
# CT      746
# TX      579
# VA      402
# IN      369
# MA      369
# MD      325
# NC      301
# GA      266
# OH      194
# IL      171
# CA      155
# ME      143
# AZ      143
# TN      131
# SC       94
# DE       85
# MI       80
# MN       72
# 99       70
# WA       68
# GV       65
# AL       63
# VT       52
# RI       49
# OK       45
# NH       44
# MO       38
# OR       32
# WI       30
# KY       28
# LA       28
# CO       26
# DC       23
# MS       19
# WV       18
# IA       14
# UT       13
# AR       13
# NM       11
# NV        8
# KS        7
# SD        7
# ON        7
# QB        7
# MT        7
# ID        6
# NE        5
# DP        4
# AB        4
# AK        3
# ND        3
# HI        2
# PR        2
# FO        1
# WY        1
# Name: Registration State, dtype: int64

# %%
df['Vehicle Make'].value_counts()
# Out:
# HONDA    5688
# TOYOT    5402
# FORD     5027
# NISSA    4478
# CHEVR    2880
#          ...
# Audi        1
# VOLZ        1
# Volks       1
# CITRO       1
# MECOX       1
# Name: Vehicle Make, Length: 168, dtype: int64

# %%
df.describe()
# Out:
#        Summons Number  Violation Code  Street Code1  Street Code2  \
# count    5.000000e+04    50000.000000  50000.000000  50000.000000
# mean     7.017655e+09       31.944140  19683.326600  16648.178160
# std      2.258812e+09       16.088848  22499.739403  21237.655634
# min      1.254533e+09        0.000000      0.000000      0.000000
# 25%      4.708005e+09       20.000000      0.000000      0.000000
# 50%      8.729645e+09       36.000000  12720.000000  10210.000000
# 75%      8.815425e+09       38.000000  34210.000000  27050.000000
# max      8.880300e+09       99.000000  95130.000000  98100.000000
#
#        Street Code3  Vehicle Expiration Date  Violation Location  \
# count  50000.000000             5.000000e+04        32108.000000
# mean   16489.137900             2.263959e+07           55.419179
# std    21342.886145             2.874199e+07           37.929945
# min        0.000000             0.000000e+00            1.000000
# ...

# %%
df.hist(bins=50, figsize=(20, 15))


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
# ...

# %%
# fig = plt.figure(figsize=(10, 7))
# plt.boxplot(df['Summons Number'])

# plt.show()

# %%
import csv
import seaborn as sns

# %%
ny_datatick=df.groupby(by='Registration State', as_index=False).count()
ny_datatick.head()
# Out:
#   Registration State  Summons Number  Plate ID  Plate Type  Issue Date  \
# 0                 99              70        70          70          70
# 1                 AB               4         4           4           4
# 2                 AK               3         3           3           3
# 3                 AL              63        63          63          63
# 4                 AR              13        13          13          13
#
#    Violation Code  Vehicle Body Type  Vehicle Make  Issuing Agency  \
# 0              70                 62            65              70
# 1               4                  4             4               4
# 2               3                  3             3               3
# 3              63                 62            63              63
# 4              13                 13            13              13
#
#    Street Code1  ...  Vehicle Year  Meter Number  Feet From Curb  \
# 0            70  ...            70            49              70
# ...

# %%
columns_ny=ny_datatick[['Registration State', 'Summons Number']]
columns_ny.head()
# Out:
#   Registration State  Summons Number
# 0                 99              70
# 1                 AB               4
# 2                 AK               3
# 3                 AL              63
# 4                 AR              13

# %%
columns_city=columns_ny[columns_ny['Registration State']!='99']
columns_city.head()
# Out:
#   Registration State  Summons Number
# 1                 AB               4
# 2                 AK               3
# 3                 AL              63
# 4                 AR              13
# 5                 AZ             143

# %%
columns_cities=columns_city[columns_city['Registration State']!='NY']
columns_cities.head()
# Out:
#   Registration State  Summons Number
# 1                 AB               4
# 2                 AK               3
# 3                 AL              63
# 4                 AR              13
# 5                 AZ             143

# %%
plt.figure(figsize=(13, 6))
x=columns_ny['Summons Number']
y=columns_ny['Registration State']

# x=['Summons Number']
# y=['Registration State']


plt.bar(y,x, color='b', width =0.75)

plt.xticks( rotation=90)


plt.title("Number of Parking Tickets Given for Each State registered car", fontsize=16)

plt.xlabel("Registration State", fontsize=18)

plt.ylabel("Number of Cars", fontsize=18)



plt.show()

# %% [markdown]
# #  Conclusion: From this we can conclude, that majorities tickets were issued to the locals of New Yorks, followed by New Jersey and Pennsylvania

# %%
ny_datatick=df.groupby(by='Vehicle Make', as_index=False).count()
ny_datatick.head()
# Out:
#   Vehicle Make  Summons Number  Plate ID  Registration State  Plate Type  \
# 0        A5 2.               1         1                   1           1
# 1        ACOUR               1         1                   1           1
# 2         ACUR               1         1                   1           1
# 3        ACURA            1042      1042                1042        1042
# 4        ALFAR              32        32                  32          32
#
#    Issue Date  Violation Code  Vehicle Body Type  Issuing Agency  \
# 0           1               1                  0               1
# 1           1               1                  1               1
# 2           1               1                  1               1
# 3        1042            1042               1041            1042
# 4          32              32                 32              32
#
#    Street Code1  ...  Vehicle Year  Meter Number  Feet From Curb  \
# 0             1  ...             1             1               1
# ...

# %%
columns_nx=ny_datatick[['Vehicle Make', 'Summons Number']]
columns_nx.head(100)
# Out:
#    Vehicle Make  Summons Number
# 0         A5 2.               1
# 1         ACOUR               1
# 2          ACUR               1
# 3         ACURA            1042
# 4         ALFAR              32
# ..          ...             ...
# 95        MAZDA             652
# 96        ME/BE            2348
# 97        MECOX               1
# 98        MERCU             104
# 99           MG               1
#
# [100 rows x 2 columns]

# %%
# x=['Summons Number']
# y=['Registration State']


# plt.bar(y, x, color='r', width =0.75, align='edge')

# plt.xticks( rotation=90)


# plt.title("Number of Parking Tickets Given for Each Vehicle Make", fontsize=18)

# plt.xlabel("Vehicle Make", fontsize=18)

# plt.ylabel("Number of Cars", fontsize=18)



# plt.show()

plt.figure(figsize=(64, 24))
x=columns_nx['Summons Number']
y=columns_nx['Vehicle Make']

plt.bar(y, x, color='r', width =0.75, align='edge')

plt.xticks( rotation=90)


plt.title("Number of Parking Tickets Given for Each Vehicle Make", fontsize=65)

plt.xlabel("Vehicle Make", fontsize=60)

plt.ylabel("Number of Cars", fontsize=60)


plt.show()

# %% [markdown]
# #  Analysis: in this analysis, i am analysing monthly tickets issues to the locals of new york with other states.

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Summons Number, Plate ID, Registration State, Plate Type, Issue Date, Violation Code, Vehicle Body Type, Vehicle Make, Issuing Agency, Street Code1, Street Code2, Street Code3, Vehicle Expiration Date, Violation Location, Violation Precinct, Issuer Precinct, Issuer Code, Issuer Command, Issuer Squad, Violation Time, Time First Observed, Violation County, Violation In Front Of Or Opposite, House Number, Street Name, Intersecting Street, Date First Observed, Law Section, Sub Division, Violation Legal Code, Days Parking In Effect    , From Hours In Effect, To Hours In Effect, Vehicle Color, Unregistered Vehicle?, Vehicle Year, Meter Number, Feet From Curb, Violation Post Code, Violation Description, No Standing or Stopping Violation, Hydrant Violation, Double Parking Violation, Unnamed: 43, Unnamed: 44]
# Index: []
#
# [0 rows x 45 columns]

# %%
df.shape
# Out:
# (50113, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50113 entries, 0 to 50112
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Summons Number                     50000 non-null  float64
#  1   Plate ID                           50000 non-null  object
#  2   Registration State                 50000 non-null  object
#  3   Plate Type                         50000 non-null  object
#  4   Issue Date                         50000 non-null  object
#  5   Violation Code                     50000 non-null  float64
#  6   Vehicle Body Type                  49855 non-null  object
#  7   Vehicle Make                       49864 non-null  object
#  8   Issuing Agency                     50000 non-null  object
#  9   Street Code1                       50000 non-null  float64
#  10  Street Code2                       50000 non-null  float64
# ...

# %%
df.shape[0]
# Out:
# 50113

# %%
df.isnull().sum()
# Out:
# Summons Number                         113
# Plate ID                               113
# Registration State                     113
# Plate Type                             113
# Issue Date                             113
# Violation Code                         113
# Vehicle Body Type                      258
# Vehicle Make                           249
# Issuing Agency                         113
# Street Code1                           113
# Street Code2                           113
# Street Code3                           113
# Vehicle Expiration Date                113
# Violation Location                   18005
# Violation Precinct                     113
# Issuer Precinct                        113
# Issuer Code                            113
# Issuer Command                       17969
# Issuer Squad                         17969
# Violation Time                         114
# Time First Observed                  48224
# Violation County                       230
# ...

# %%
df.shape[0]
# Out:
# 50113

# %%
no_na=df.dropna()

# %%
no_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Summons Number                     0 non-null      float64
#  1   Plate ID                           0 non-null      object
#  2   Registration State                 0 non-null      object
#  3   Plate Type                         0 non-null      object
#  4   Issue Date                         0 non-null      object
#  5   Violation Code                     0 non-null      float64
#  6   Vehicle Body Type                  0 non-null      object
#  7   Vehicle Make                       0 non-null      object
#  8   Issuing Agency                     0 non-null      object
#  9   Street Code1                       0 non-null      float64
#  10  Street Code2                       0 non-null      float64
# ...

# %%
df.isnull()
# Out:
#        Summons Number  Plate ID  Registration State  Plate Type  Issue Date  \
# 0               False     False               False       False       False
# 1               False     False               False       False       False
# 2               False     False               False       False       False
# 3               False     False               False       False       False
# 4               False     False               False       False       False
# ...               ...       ...                 ...         ...         ...
# 50108            True      True                True        True        True
# 50109            True      True                True        True        True
# 50110            True      True                True        True        True
# 50111            True      True                True        True        True
# 50112            True      True                True        True        True
#
# ...

# %%
new_df = df.dropna(subset=['Plate ID', 'Registration State', 'Vehicle Make', 'Vehicle Color', 'Street Code1', 'Violation Time'])

# %%
new_df
# Out:
#        Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0        4.714702e+09  KGK6659                 NY        PAS    11-12-20
# 1        8.793685e+09  L5232HY                 TN        PAS  09/14/2020
# 2        8.864757e+09   BPMN76                 FL        PAS  11/25/2020
# 5        4.708209e+09  KDW9420                 NY        PAS  09/21/2020
# 6        8.818510e+09  HLB4150                 NY        PAS  07/14/2020
# ...               ...      ...                ...        ...         ...
# 49995    4.014246e+09  JPN4910                 NY        PAS  06/25/2020
# 49996    8.794438e+09   174ZYG                 CT        PAS  08/25/2020
# 49997    8.849770e+09  HES6895                 NY        PAS    11-03-20
# 49998    8.755448e+09  63035MN                 NY        COM  08/19/2020
# 49999    8.581528e+09  AW74165                 CT        PAS    08-06-20
#
#        Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47454 entries, 0 to 49999
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Summons Number                     47454 non-null  float64
#  1   Plate ID                           47454 non-null  object
#  2   Registration State                 47454 non-null  object
#  3   Plate Type                         47454 non-null  object
#  4   Issue Date                         47454 non-null  object
#  5   Violation Code                     47454 non-null  float64
#  6   Vehicle Body Type                  47352 non-null  object
#  7   Vehicle Make                       47454 non-null  object
#  8   Issuing Agency                     47454 non-null  object
#  9   Street Code1                       47454 non-null  float64
#  10  Street Code2                       47454 non-null  float64
# ...

# %%
# plot a histogram of the data 
plot, ax=plt.subplots()
plt.style.use('fivethirtyeight')

ax.hist(df['Vehicle Year'], range (1998, 2022));

ax.set_xlabel('Years')
ax.set_ylabel('Total Number of Vehicles')
ax.set_title('No. of vehicle registered each year')
# Out:
# Text(0.5, 1.0, 'No. of vehicle registered each year')

# %%
# plot a histogram of the data 
plot, ax=plt.subplots()
plt.style.use('fivethirtyeight')

ax.hist(df['Plate Type'], range(10, 20));


ax.set_xlabel('Plate Type')
ax.set_ylabel('No of plate type')
ax.set_title('No. of palte type in data set')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/d9/bnlf1kp95215c4604jd3mz1h0000gn/T/ipykernel_81309/683510278.py in <module>
#       3 plt.style.use('fivethirtyeight')
#       4
# ----> 5 ax.hist(df['Plate Type'], range(10, 20));
#       6
#       7
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6554         if orientation == "vertical":
# ...

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#  No NA's in dataset
No_NAs = df.dropna(subset=['Plate ID', 'Registration State', 'Vehicle Make', 'Vehicle Color', 'Street Code1', 'Violation Time'])

# %%
# Nas removed 
No_NA=df.shape[0] - No_NAs.shape[0]

# %%
print(f'The number of NAs in the dataset: {No_NA}')
# Out:
# The number of NAs in the dataset: 2659

# %%
# A function that finds the mean of list of items in a list
def my_mean(numbers):
    return sum(numbers)/len(numbers)
my_mean([4, 6])
# Out:
# 5.0

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as py

# %%
df= pd.read_csv(r"C:\Users\user\Desktop\AZUBI AFRICA\week9\violations.csv")

# %%
df

# %%
df.columns
